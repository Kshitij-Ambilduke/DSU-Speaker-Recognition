# %%
import pandas as pd

# %%
df = pd.read_csv("/mnt/data-artemis/kshitij/TEMP/Speaker-recognition/DSU_creation/VCTK/final_data_vctk/train.csv")
df.head()
# Out:
#    Unnamed: 0                                               file  \
# 0           0  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 1           1  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 2           2  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 3           3  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 4           4  /mnt/data-poseidon/kshitij/Speaker-recognition...
#
#                                                 text speaker_id  \
# 0                                 it's a way of life       p229
# 1  he said the matter had been neglected in the past       p229
# 2  the work between the musicians and the fire is...       p229
# 3  it should be an enjoyable and challenging peri...       p229
# 4  i have every confidence in raymond robertson a...       p229
#
#                                                  DSU
# 0  1386 1416 443 374 152 796 246 7 7 299 299 299 ...
# 1  1384 1522 1522 1445 152 868 1369 1369 1369 136...
# ...

# %%
df['label'] = pd.Categorical(df['speaker_id']).codes

# %%
# Out:
#        Unnamed: 0                                               file  \
# 0               0  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 1               1  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 2               2  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 3               3  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 4               4  /mnt/data-poseidon/kshitij/Speaker-recognition...
# ...           ...                                                ...
# 10045       10045  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 10046       10046  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 10047       10047  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 10048       10048  /mnt/data-poseidon/kshitij/Speaker-recognition...
# 10049       10049  /mnt/data-poseidon/kshitij/Speaker-recognition...
#
#                                                     text speaker_id  \
# 0                                     it's a way of life       p229
# ...
